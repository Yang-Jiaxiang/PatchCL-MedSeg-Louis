# %%
import pandas as pd

# 讀取 CSV 檔案
csv_file_path = 'output/supervised pre training_loss-Resnet18_Image-224_patchSize-14_ContrastieWeights-0.1.csv'  # 請將此處替換為你的 CSV 檔案路徑
df = pd.read_csv(csv_file_path)
df.head()
# Out:
#    t_loss  t_supervised_loss  t_contrastive_loss  t_consistency_loss  t_miou  \
# 0  1.0756             0.3290              7.4668                   0  0.1568
# 1  1.1639             0.3618              8.0209                   0  0.2874
# 2  1.2292             0.3862              8.4303                   0  0.2766
# 3  1.2887             0.3924              8.9629                   0  0.3519
# 4  1.2895             0.3186              9.7090                   0  0.2992
#
#    t_accuracy  t_dice  v_loss  v_supervised_loss  v_contrastive_loss  \
# 0      0.6275  0.2089  0.3164             0.3164                   0
# 1      0.7450  0.3627  0.3162             0.3162                   0
# 2      0.7335  0.3535  0.3048             0.3048                   0
# 3      0.8024  0.4111  0.3424             0.3424                   0
# 4      0.7569  0.3722  0.2708             0.2708                   0
#
#    v_consistency_loss  v_miou  v_accuracy  v_dice                 time
# 0                   0  0.3172      0.7672  0.3923  2024-05-23 01:14:14
# 1                   0  0.3139      0.7688  0.3823  2024-05-23 01:16:23
# 2                   0  0.2966      0.7546  0.3702  2024-05-23 01:18:37
# 3                   0  0.3669      0.8149  0.4223  2024-05-23 01:20:57
# 4                   0  0.2645      0.7273  0.3450  2024-05-23 01:23:24

# %%
import matplotlib.pyplot as plt

plt.plot(df['t_supervised_loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(df['supervised_loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
